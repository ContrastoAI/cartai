# %%
from cartai.core.code_parser import ProjectParser


parser = ProjectParser()

parser.parse("../cartai")

print(parser.get_summary("../cartai"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       4 parser = ProjectParser()
#       6 parser.parse("../cartai")
# ----> 8 print(parser.get_summary("../cartai"))
#
# File D:\GitHub\cartai\cartai\core\code_parser.py:256, in ProjectParser.get_summary(self, path)
#     253 path = Path(path)
#     254 structure = self.parse(path)
# --> 256 return self._format_summary(structure)
#
# File D:\GitHub\cartai\cartai\core\code_parser.py:267, in ProjectParser._format_summary(self, structure, indent)
#     265         result.append(self._format_summary(item, indent + 1))
#     266 else:  # file
# --> 267     file_info = f"{'  ' * indent}📄 {structure.name}"
#     268     if structure.error:
#     269         file_info += f" ({structure.error})"
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
parser = ProjectParser(include_basic_entities=True)

parser.parse("../.")
# Out:
# {'type': 'directory',
#  'name': '..',
#  'path': WindowsPath('..'),
#  'error': None,
#  'contents': [{'type': 'file',
#    'name': '.env.example',
#    'path': WindowsPath('../.env.example'),
#    'error': None,
#    'extension': '.example',
#    'size_kb': 0.03,
#    'entities': {},
#    'content': ''},
#   {'type': 'file',
#    'name': '.pre-commit-config.yaml',
#    'path': WindowsPath('../.pre-commit-config.yaml'),
#    'error': None,
#    'extension': '.yaml',
#    'size_kb': 0.77,
#    'entities': {},
# ...
